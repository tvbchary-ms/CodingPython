# %% [markdown]
# # Working with files in Python
#
# #### 🔹 Opening a File
#
# ##### Purpose
# - Opening files is required for reading logs, writing reports, handling configs, backups, and automation tasks in DevOps.

# %% [markdown]
# ##### Common File Modes (Important)
#
# | Mode | Meaning           | DevOps use         |
# | ---- | ----------------- | ------------------ |
# | `r`  | Read              | Read logs/configs  |
# | `w`  | Write (overwrite) | Write reports      |
# | `a`  | Append            | Append logs        |
# | `x`  | Create new file   | Safe file creation |

# %% [markdown]
# #### Notes
# - open() → opens a file
# - Always close files (or use with)
# - a mode is best for logs
# - with is safer and cleaner

# %%
# open() function
# Syntax
# open(filename, mode)
file = open("test_file_ops.txt", "r")


# Reading a File
content = file.read() # reads entire file
print(content)
file.close()
# Out:
# test line 1
# test line 2
# test line 3
# test line 4
# test line 5
# test line 6
# test line 7
# test line 8
# test line 9
# test line 10

# %%
# Creating and Writing to a File
file = open("output.txt", "w")
file.write("Deployment successful")
file.close()

# %%
file = open("app.log","r")
content = file.read()
print(content)

# %%
# ppending to an exitsing File (Logs)
file = open("app.log", "a") # Appends to existing data  like >> in Linux
file.write("\nService restarted")
file.close()

file = open("test_file_ops.txt", "w") # deletes content and wrotes data like > in Linux
file.write("\nNew line 1")
file.close()

# %%
# Using with (Recommended)
# Automatically closes the file (best practice)
with open("test_file_ops.txt", "r") as file:
    print(file.read())
# Out:
# New line 1

# %%
# Simple DevOps Example
# Write deployment status to a file

from datetime import datetime

with open("deploy.log", "a") as f:
    f.write(f"Deployment completed at {datetime.now()}\n")

# %%
# Read line by line
with open("test_file_ops.txt", "r") as one:
    for line in one:
        print(line, end="")
# Out:
# New line 1
# New line 2

# %%
# readline() function
# This allows us to read file One line at a time

with open("test_file_ops.txt", "r") as f:
    print(f.readline())
# Out:
# New line 1

# %% [markdown]
# #### Manipulating Files in Python
#
# ##### Purpose
# - File manipulation is common in DevOps for log rotation, cleanup scripts, backups, and validation checks.
#
# ##### Notes
# - os.rename() → rename files
# - os.remove() → delete files
# - os.path.exists() → check existence
# - os.path.getsize() → file size
# - os.path.getmtime() → last modified time

# %%
# Renaming a File
# Used in log rotation or versioning (in DevOps Scope)
import os

os.rename("new.log", "app.log")

# %%
# Deleting a File
# Used to clean temporary or old files in DevOps Scope
import os

os.remove("backu_app.log")

# %%
# Other Common File Manipulations (os.path)
#  Check if file exists

import os

if os.path.exists("app.log"):
    print("File exists")
else:
    print("File does not exist")
# Out:
# File exists

# %%
# Get file size (bytes)
# Used to check large log files in DevOps Scope
import os

size = os.path.getsize("app.log")
print(size/1000,"kb")
# Out:
# 0.221 kb

# %%
# Get last modified time
# Used for backup or cleanup decisions in DevOps Scope
import os
from datetime import datetime

mtime = os.path.getmtime("app.log") # gives last modified unix timestamp
print(f"actual unix timestamp in ms {int(mtime*1000)}")
print(datetime.fromtimestamp(mtime))
# Out:
# actual unix timestamp in ms 1769458726000
# 2026-01-27 01:48:46

# %%
# Check if path is a file or directory
import os

print(os.path.isfile("app.log"))
print(os.path.isdir("logs"))
# Out:
# True
# True

# %%
# Simple DevOps Example

# Delete old log if size is too big !

import os

if os.path.exists("app.log"):
    if os.path.getsize("backup_app.log") < 10_00_000:
        os.remove("backup_app.log")

# %% [markdown]
# #### os Module
#
# - Used for low-level file and directory operations and checks.
#
# #### Common os functions
# | Function             | Purpose         |
# | -------------------- | --------------- |
# | `os.rename()`        | Rename files    |
# | `os.remove()`        | Delete files    |
# | `os.listdir()`       | List directory  |
# | `os.path.exists()`   | Check existence |
# | `os.path.getsize()`  | File size       |
# | `os.path.getmtime()` | Last modified   |
# | `os.path.isfile()`   | Check file      |
# | `os.path.isdir()`    | Check directory |
#
# - os.path.join() is used to safely combine directory paths and file names into a single valid file path, in an OS-independent way.

# %% [markdown]
# #### shutil Module
#
# - Used for high-level operations (copying & deleting directories).
#
# | Function            | Purpose            |
# | ------------------- | ------------------ |
# | `shutil.copy()`     | Copy file          |
# | `shutil.copy2()`    | Copy with metadata |
# | `shutil.copytree()` | Copy directory     |
# | `shutil.move()`     | Move files         |
# | `shutil.rmtree()`   | Delete directory   |

# %%
#### Real DevOps Cleanup Scripts
# Script 1: Delete Old Log Files (>7 days)
import os
import time

LOG_DIR = "logs"
DAYS = 7
now = time.time()

for file in os.listdir(LOG_DIR):
    path = os.path.join(LOG_DIR, file)
    if os.path.isfile(path):
        if now - os.path.getmtime(path) > DAYS * 86400: #86400 Seconds = 1 day
            os.remove(path)

# %%
# Script 2: Delete Large Log Files (>100MB)
import os

LOG_FILE = "app.log"
MAX_SIZE = 100 * 1024 * 1024  # 100MB

if os.path.exists(LOG_FILE):
    if os.path.getsize(LOG_FILE) > MAX_SIZE:
        os.remove(LOG_FILE)

# %%
# Script 3: Clean Build Artifacts (CI/CD)
import shutil
import os

folders = ["build", "dist", "__pycache__"]

for folder in folders:
    if os.path.exists(folder):
        shutil.rmtree(folder)

# %%
# Script 4: Archive Logs Before Cleanup 
import shutil
from datetime import datetime

timestamp = datetime.now().strftime("%Y%m%d")
shutil.make_archive(f"logs_backup_{timestamp}", "zip", "logs")
# Out:
# '/Volumes/BACHI/CodingPython/logs_backup_20260127.zip'

# %%
# Script 5: Safe File Delete (Check First)
import os

file = "temp.txt"

if os.path.exists(file) and os.path.isfile(file):
    os.remove(file)

# %% [markdown]
# #### Working with Directories
# #### Purpose
# - Directory operations are common in DevOps for log management, backups, deployments, CI/CD cleanup, and automation.
#
# #### Notes
# - os.mkdir() → single directory
# - os.makedirs() → nested directories
# - os.rmdir() → empty directory only
# - shutil.rmtree() → delete everything
# - Always check existence before delete

# %%
import os
is_dir = os.path.exists("test_dir")

if not is_dir:
    os.mkdir("test_dir")

# %%
# Create nested directories
import os
is_dir = os.path.exists("test_dir1")

if not is_dir:
    os.makedirs("backup/2026/jan")

# %% [markdown]
# #### Changing Directory in Python
#
# - os.chdir()
#
# ##### Purpose
# - os.chdir() is used to change the current working directory of a Python script.
# - In DevOps, this is useful when scripts need to operate inside specific folders (logs, builds, backups, deployments).
#
# ##### Notes
# - os.chdir() → changes working directory
# - Affects relative paths after change
# - Use os.getcwd() to verify
# - Always handle errors
#
# ##### ⚠️ Important Tip
#
# - Changing directories in large scripts can be confusing.
# Prefer absolute paths or os.path.join() when possible.

# %%
#Syntax
import os

os.chdir("/path/to/dir")

# Check Current Directory
import os

print(os.getcwd())

# %%
#DevOps Use Case

# Process log files inside a directory

import os

os.chdir("logs")

for file in os.listdir():
    print(file)

# %%
# Safe Directory Change (Best Practice)
import os

path = "/backup"

if os.path.exists(path) and os.path.isdir(path):
    os.chdir(path)
else:
    print("Directory not found")

# Error Handling
import os

try:
    os.chdir("/invalid/path")
except FileNotFoundError:
    print("Directory does not exist")
# Out:
# Directory not found
# Directory does not exist

# %% [markdown]
# #### Error Handling and Exceptions in Python
#
# ##### Purpose
# - Error handling allows a program to handle failures gracefully instead of crashing.
# In DevOps, this is critical for automation scripts, CI/CD pipelines, monitoring, and reliability.
#
# ##### What is an Error vs Exception?
# - Error → issue in code logic (syntax, indentation)
# - Exception → runtime problem that can be handled
# - Example exceptions:
# 1. File not found
# 2. Division by zero
# 3. Invalid input

# %%
#Common Parsing Errors (Syntax Errors)

# Occur when Python cannot parse the code

if x == 10
    print(x)

# ❌ Missing : → SyntaxError
# 🧠 Parsing errors happen before execution and cannot be caught using try-except.
# Out:
#   Cell In[8], line 5
#     if x == 10
#               ^
# SyntaxError: expected ':'

# %%
# Using try-except
try:
    result=10/0
except ZeroDivisionError:
    print("Cannot divide by zero")
# Out:
# Cannot divide by zero

# %%
# Handling Multiple Exceptions
try:
    file = open("config.txt", "r")
    print(file.read())
except FileNotFoundError:
    print("File not found")
except PermissionError:
    print("Permission denied")
# Out:
# File not found

# %%
# Catching All Exceptions (Use Carefully)
try:
    x = int("abc")
except Exception as e:
    print("Error:", e)
# Out:
# Error: invalid literal for int() with base 10: 'abc'

# %%
# else with try-except
try:
    x = int("10")
except ValueError:
    print("Invalid number")
else:
    print("Conversion successful:", x)
# Out:
# Conversion successful: 10

# %%
# finally Block
try:
    file = open("app.log", "r")
    print(file.read())
except FileNotFoundError:
    print("File missing")
finally:
    print("Cleanup done")
# Out:
# app deployed successfully!
# Cleanup done

# %%
# Handling Multiple Exceptions Together

# Purpose
# This pattern allows you to:
# Handle specific known exceptions first
# Catch any unexpected errors separately 

# Syntax Example
try:
    # some risky code
    x = int("abc")      # ValueError
    y = x + "10"        # TypeError
except (ValueError, TypeError):
    print("There seems to be a value or type issue.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# There seems to be a value or type issue.

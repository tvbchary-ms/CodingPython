# %% [markdown]
# # Basic Coding and Python Cheatsheet

# %% [markdown]
# ### Converting Binary to Decimal and Hexadecimal

# %% [markdown]
# ### Pythonfor DevOps
#
# #### - “Master automation, CI/CD pipelines, andcontainerization with Python DevOps strategies”
#
# ##### Important Notes

# %%
string = "Hello World"

print(string if not " " in string else "space is there")
# Out:
# space is there

# %% [markdown]
# ## “Variables, data types, and structures”
#
# #### Variables are used to store values
# #### Datatypes are type of data stored in  a Variable
#      - Integers (int) - stores whole numbers (positive or negative)
#      - Floats (float) - Floating point numbers with decimal
#      - Strings (str) - strings are series of characters
#      - Booleans (bool) - Logical values True or False
# ##### type()
#      - type() function is used to output the datatype of a give value/variable

# %%
# Type function usage
number = 10
name ="John"
percent = 70.5
is_active = True

# Printing type of a variable
print(type(name))

# Printing type of a value
print(type(100))

# check datatype condition
#if type(is_active).__name__== 'bool':
# OR
if type(is_active)== bool:
    print ("Yes, it is a logical value ")
else:
    print ("No it is not")
# Out:
# <class 'str'>
# <class 'int'>
# Yes, it is a logical value

# %%
# more examples
x = 3.14
print(type(x).__name__)   # float

y = "hello"
print(type(y).__name__)   # str

z = [1, 2, 3]
print(type(z).__name__)   # list
# Out:
# float
# str
# list

# %% [markdown]
# #### Structures
#
# - Lists:  Dynamic arrays, mutable, defined using [] - square brackets
# - Tuples: similar to lists but immutable, defines using () - parenthesis
# - Dictionaries: collections, defined using {} - curly braces. key-value pairs,
#    mutable, uses keys to represent values
#    e.g. person = {
# 			     "name": "Alice",
# 			     "age": 30,
# 			     "city": "New York"
# 			 }
#         person["name"] = Alice
# - sets : unordered collection, mutable ,like dictionaries uses {} - curly braces to define, but only has individual values, automatically eliminates duplicate values, suitable for set ops like union, difference, intersection etc.
#    e.g u_nums = {1,2,2,3,3,3,4,4,4} # output = {1,2,3,4}

# %%
# Examples 
# 1. Lists
# Dynamic arrays, mutable, defined using []

numbers = [10, 20, 30, 40]

print(numbers)        # [10, 20, 30, 40]

numbers.append(50)    # add element
print(numbers)        # [10, 20, 30, 40, 50]

numbers[1] = 25       # modify element
print(numbers)        # [10, 25, 30, 40, 50]
# Out:
# [10, 20, 30, 40]
# [10, 20, 30, 40, 50]
# [10, 25, 30, 40, 50]

# %%
# 2. Tuples
# Dynamic arrays, mutable, defined using []
colors = ("red", "green", "blue")

print(colors)         # ('red', 'green', 'blue')

print(colors[0])      # red

#colors[1] = "yellow"   #❌ Error (cannot modify tuple)
# Out:
# ('red', 'green', 'blue')
# red

# %%
# 3. Dictionaries
#Key–value pairs, mutable, defined using {}

person = {
    "name": "Alice",
    "age": 30,
    "city": "New York"
}

print(person["name"])     # Alice

person["age"] = 31        # update value
print(person)

person["country"] = "USA" # add new key-value
print(person)
# Out:
# Alice
# {'name': 'Alice', 'age': 31, 'city': 'New York'}
# {'name': 'Alice', 'age': 31, 'city': 'New York', 'country': 'USA'}

# %%
# 4. Sets
# Unordered collection, mutable, no duplicates, defined using {}
u_nums = {1, 2, 2, 3, 3, 3, 4, 4, 4}

print(u_nums)   # {1, 2, 3, 4}

a = {1, 2, 3}
b = {3, 4, 5}

# Set operations example
print(a | b)   # Union → {1, 2, 3, 4, 5}
print(a & b)   # Intersection → {3}
print(a - b)   # Difference → {1, 2}
print(b - a)   # Difference → {4, 5}
# Out:
# {1, 2, 3, 4}
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}
# {4, 5}

# %% [markdown]
# ### Control structures
#
# ##### Conditional statements
#  - if, elif and else
#
# ##### Loops
#  - for loop
#  - while loop
#  - break statement - control mechanism
#  - continue statement - control mechanism

# %%
# if example

# Initialize the variable `age` with a value of 16
age = 21

# Check if the age is less than 18
if age < 18:
    # Print this message if the person is a minor
    print("You are a minor!")
# Check if the age is exactly 18
elif age == 18:
    # Print this message if the person just became an adult
    print("You just became an adult!")
# If age is greater than 18
else:
    # Print this message if the person is an adult
    print("You are an adult!")
# Out:
# You are an adult!

# %%
# for loop

# Used when the number of iterations is known.
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# while loop
# Used when the condition is checked repeatedly.
count = 1

while count <= 5:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Loop Control Mechanisms
# Stops the loop completely when condition is met.

for i in range(1, 10):
    print(i)
    if i == 5:
        break
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# continue statement
for i in range(1, 6):
    if i == 3:
        continue # skips printing 3 
    print(i)
# Out:
# 1
# 2
# 4
# 5

# %% [markdown]
# #### Functions
# - Define a function using the key word def and using arguments.
# e.g. def greet(name):
# 		print(f"Hello, {name}!")
#
# - Calling a function, e.g. greet("Alice")  # Outputs: Hello, Alice!
# - Returning values.
# e.g. def add_numbers(a, b):
# 	    return a + b
#     result = add_numbers(5,3) # result now holds the value 8

# %%
# Defining a function using def and arguments
# def → used to define a function
# Arguments → values passed to a function
def welcome(user):
    print(f"Welcome, {user}!")

# %%
# Calling a function
welcome("Rahul")   # Outputs: Welcome, Rahul!
# Out:
# Welcome, Rahul!

# %%
# Function with multiple arguments
def multiply(a, b):
    print(a * b)

multiply(4, 5)     # Outputs: 20
# Out:
# 20

# %%
# Returning values from a function
# return → sends value back to caller
# Code inside function runs only when called
def square(num):
    return num * num

result = square(6)   # result now holds the value 36
print(result)
# Out:
# 36

# %%
# Function that both prints and returns
def calculate_total(price, tax):
    total = price + tax
    print("Total amount:", total)
    return total

bill = calculate_total(100, 18)
# Out:
# Total amount: 118

# %%
# Real-world example
def is_eligible(age):
    if age >= 18:
        return "Eligible"
    else:
        return "Not eligible"

status = is_eligible(20)
print(status)
# Out:
# Eligible

# %% [markdown]
# ### Modules
# - In Python, a module refers to a file containing executable code, be it functions, variables, or classes, that can be leveraged by other programs or scripts.
# - Modules are a way of organizing and segmenting code to improve code reusability and manageability.
# - By segregating functionalities into distinct modules, developers can maintain a clean and organized codebase, making it easier to debug, modify, and enhance.

# %% [markdown]
# #### Creating a module
#
# - To create a module in Python, one simply needs to save the code they want to include in a file with a .py extension.
# - his file can contain functions, classes, and variables, as well as runnable code.
#
# #### Using a module
# - Once a module is created, its functionalities can be accessed in another Python script or program by using the import statement.

# %%
# Module example, creating a math_ops.py file and importing it here
# importing entire module and calling functions using module name
import math_ops

result = math_ops.add(10,5)
print (result)
# Out:
# 15

# %%
# importing specific function from the module math_ops
from math_ops import subtract, add

result = add(10,5)
print (result)

result = subtract(10,5)
print(result)
# Out:
# 15
# 5

# %% [markdown]
# ### Built-in Modules
#
# - Python provides many ready-to-use built-in modules that simplify common tasks.
# In DevOps, these modules help in system operations, file handling, automation, and environment management.

# %% [markdown]
# 🔹 os module
#
# Provides a portable way to interact with the operating system (files, directories, environment variables, etc.).
#
# - os → interacts with the operating system
#
# - Used for files, directories, environment variables
#
# - Platform-independent (works on Linux, macOS, Windows)

# %%
# importing os module
import os

# Get current working directory
cwd = os.getcwd()
print(cwd)

# List files and folders in a directory
files = os.listdir(".")
print(files)

# %%
# Create a new directory
import os

os.mkdir("logs")
print("Directory created")
# Out:
# Directory created

# %%
# Check if a file or directory exists
import os

if os.path.exists("logs"):
    print("Directory exists")
else:
    print("Directory not found")
# Out:
# Directory exists

# %%
# Get environment variables (very useful in DevOps)
import os

path = os.environ.get("PATH")
print(path)

# %%
# Run a system command
import os

os.system("ls")   # Linux / macOS
# os.system("dir")  # Windows
# Out:
# 0

# %%
# Real-world DevOps example

# Check and create a directory for logs
import os

if not os.path.exists("app_logs"):
    os.mkdir("app_logs")

print("Log directory ready")
# Out:
# Log directory ready

# %% [markdown]
# 🔹 sys module
#
# Grants access to Python interpreter variables and functions and allows interaction with the Python runtime environment.
#
# - sys.argv → command-line arguments
#
# - sys.exit() → stop execution
#
# - sys.version → Python version info
#
# - Used heavily in CLI tools & automation

# %%
# Importing the sys module
import sys

# Access command-line arguments

print(sys.argv)

# Example run:
# python script.py dev 8080

# Output:
#['script.py', 'dev', '8080']

# Access individual arguments:
# env = sys.argv[1]
# port = sys.argv[2]

#print(env, port)

# %%
# Get Python version
import sys

print(sys.version)
# Out:
# 3.13.11 (main, Dec  5 2025, 16:06:33) [Clang 17.0.0 (clang-1700.4.4.1)]

# %%
# Exit a program
# import sys

# print("Exiting program")
# sys.exit()

#With status code:
# sys.exit(1)   # non-zero → error

# Standard input
#  print("Hello", name)    # check script.py

# piped input
# echo "Alice" | python script.py
# Output:
  # Hello Alice

# Example piping terminal command
# cat names.txt | python script.py

# %%
# Real-world DevOps example

# Environment-based deployment script

import sys

if len(sys.argv) < 2:
    print("Usage: python deploy.py <env>")
    sys.exit(1)

env = sys.argv[1]

if env == "prod":
    print("Deploying to Production")
elif env == "dev":
    print("Deploying to Development")
else:
    print("Unknown environment")
# Out:
# Unknown environment

# %% [markdown]
# #### subprocess
# - 👉 Enables the spawning of new processes, connecting to their input/output/error pipes, and obtaining their return codes.
# - 👉 It is a better and safer replacement for os.system().
# ##### ❗ Why DevOps prefers subprocess
#
# - More control than os.system
# - Can capture logs
# - Can handle errors cleanly
# - Secure (no shell injection if used properly)

# %% [markdown]
# | Feature               | Meaning                      |
# | --------------------- | ---------------------------- |
# | `subprocess.run()`    | Run external command         |
# | `capture_output=True` | Capture stdout & stderr      |
# | `check=True`          | Raise error if command fails |
# | `returncode`          | Command status               |
# | `Popen`               | Advanced process control     |

# %%
### Importing the module
import subprocess

# Run a simple command

subprocess.run(["ls"]) # Mac or Linux
# subprocess.run(["dir"], shell=True)
# Out:
# CompletedProcess(args=['clear'], returncode=0)

# %%
# Capture command output
import subprocess

result = subprocess.run(
    ["echo", "Hello World"],
    capture_output=True,
    text=True
)

print(result.stdout)
# Out:
# Hello World

# %%
# Check command success (return code)
import subprocess

result = subprocess.run(["clear"])

print(result.returncode) #0 → success , # non-zero → error
# Out:
# 0

# %%
# Handle command failure
import subprocess

try:
    subprocess.run(["ls", "not_a_folder"], check=True)
except subprocess.CalledProcessError:
    print("Command failed")
# Out:
# Command failed
# ls: not_a_folder: No such file or directory

# %%
# Read both output and error

import subprocess

result = subprocess.run(
    ["ls", "not_a_folder"],
    capture_output=True,
    text=True
)

print("STDOUT:", result.stdout)
print("STDERR:", result.stderr)
# Out:
# STDOUT:
# STDERR: ls: not_a_folder: No such file or directory

# %% [markdown]
# #### Real-world DevOps example

# %%
# Check if a service is running

import subprocess

result = subprocess.run(
    ["ps", "-ef"],
    capture_output=True,
    text=True
)

if "nginx" in result.stdout:
    print("Nginx is running")
else:
    print("Nginx is not running")
# Out:
# Nginx is not running

# %%
# Pipe commands (advanced but useful)
import subprocess

p1 = subprocess.Popen(["echo", "Hello"], stdout=subprocess.PIPE)
p2 = subprocess.Popen(["wc", "-c"], stdin=p1.stdout, stdout=subprocess.PIPE)

output = p2.communicate()[0]
print(output.decode())
# Out:
#        6

# %% [markdown]
# ### socket module
#
# - A library for network communication that allows you to build clients and servers using sockets.
#
# ##### 👉 Used for:
#
# - client–server communication
# - APIs (low-level)
# - monitoring tools
# - distributed systems
#
# ##### 🧠 Simple idea
#
# - Server → listens on an IP + port
# - Client → connects to that IP + port
# - They send and receive data

# %%
# How to run
# run server.py and client.py on two separate terminals

### server.py
import socket

# create a socket
server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

# bind to IP and port
server_socket.bind(("127.0.0.1", 5000))

# listen for connections
server_socket.listen(1)
print("Server is listening...")

# accept client connection
conn, addr = server_socket.accept()
print("Connected by", addr)

# send data to client
conn.sendall(b"Hello from server")

# close connection
conn.close()
server_socket.close()

###########################
# client.py

import socket

# create a socket
client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

# connect to server
client_socket.connect(("127.0.0.1", 5000))

# receive data
data = client_socket.recv(1024)
print("Received:", data.decode())

# close connection
client_socket.close()

# %% [markdown]
# #### json Module
#
# - 📌 Purpose
# The json module helps in encoding (Python → JSON) and decoding (JSON → Python) data.
# This is very common in microservices, REST APIs, DevOps automation, and cloud tools.
#
# ##### Summary
#
# |Function |	Purpose |
# |--------- | ------- |
# |json.dumps() |	Python → JSON string |
# | json.loads() |	JSON string → Python |
# | json.dump() |	Python → JSON file |
# | json.load() |	JSON file → Python |

# %% [markdown]
# #### 📊 YAML vs JSON Comparison
#
# | Feature        | YAML                      | JSON                         |
# | -------------- | ------------------------- | ---------------------------- |
# | Readability    | ⭐ Very readable           | ❌ Less readable              |
# | Syntax         | Indentation-based         | Braces `{}` & brackets `[]`  |
# | Comments       | ✅ Supported               | ❌ Not supported              |
# | Used in DevOps | Kubernetes, Ansible, Helm | APIs, Terraform output, REST |
# | Parsing speed  | Slower                    | Faster                       |
# | Strictness     | Flexible                  | Very strict                  |

# %%
# Importing the json module
import json

# Encoding (Python → JSON)
# Converting Python objects into JSON format.
# Example: Dictionary to JSON string

data = {
    "name": "Alice",
    "age": 30,
    "city": "New York"
}

json_data = json.dumps(data) # dumps() → dump string (returns JSON as string)

print(json_data)
# Out:
# {"name": "Alice", "age": 30, "city": "New York"}

# %%
#Decoding (JSON → Python)
# Converting JSON data back into Python objects.
# Example: JSON string to Dictionary

import json

json_string = '{"name": "Bob", "age": 25, "city": "London"}'

python_data = json.loads(json_string) #loads() → load string (returns Python dict)

print(python_data)
print(python_data["name"])
# Out:
# {'name': 'Bob', 'age': 25, 'city': 'London'}
# Bob

# %%
# orking with JSON files
# Writing JSON to a file

import json

config = {
    "server": "prod",
    "port": 8080,
    "debug": False
}

with open("config.json", "w") as f:
    json.dump(config, f)

# %%
# reading JSON from a file
import json

with open("config.json", "r") as f:
    config_data = json.load(f)

print(config_data["server"])
# Out:
# prod

# %%
# Real-world (DevOps) Example
# Reading API response or config file

import json

api_response = '{"status": "success", "code": 200}'

response = json.loads(api_response)

if response["status"] == "success":
    print("API call successful")
# Out:
# API call successful

# %% [markdown]
# #### logging Module
#
# ##### Purpose
# - The logging module is used to generate logs for applications.
# - Logs help in monitoring, debugging, auditing, and troubleshooting—critical in DevOps, microservices, CI/CD, and cloud systems.
#
# ##### Why not use print()?
#
# - print() → only for simple debugging
# - logging →
# - log levels (INFO, ERROR, etc.)
# - write to files
# - timestamps
# - production-ready
#
# ##### 🔹 Logging Levels (Very Important)
#
# | Level      | Use case                |
# | ---------- | ----------------------- |
# | `DEBUG`    | Detailed debugging info |
# | `INFO`     | General app events      |
# | `WARNING`  | Something unexpected    |
# | `ERROR`    | Failure in operation    |
# | `CRITICAL` | App may crash           |

# %% [markdown]
# #####  DevOps Use Cases
#
# - CI/CD pipeline logs (Jenkins, GitHub Actions)
# - Kubernetes pod logs
# - Terraform / Ansible execution logs
# - Cloud monitoring (CloudWatch, Azure Monitor)

# %%
#import logging module
import logging

# Basic logging example
logging.basicConfig(level=logging.INFO)

logging.info("Application started")
logging.warning("Low disk space")
logging.error("Failed to connect to server")
# Out:
# INFO:root:Application started
# WARNING:root:Low disk space
# ERROR:root:Failed to connect to server

# %%
# Logging with Timestamp & Format
import logging

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

logging.info("Service started")
logging.error("Database connection failed")

# %%
# Logging to a File (Very Common in DevOps)

import logging

logging.basicConfig(
    filename="app.log",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

logging.info("App started")
logging.error("API call failed")
# Out:
# INFO:root:App started
# ERROR:root:API call failed

# %%
# Real-world DevOps Example
# Monitoring a service status

import logging

logging.basicConfig(level=logging.INFO)

def check_service(status):
    if status == "running":
        logging.info("Service is running")
    else:
        logging.error("Service is down")

check_service("running")
check_service("stopped")
# Out:
# INFO:root:Service is running
# ERROR:root:Service is down

# %%
# Logging Exceptions (Very Important)
import logging

logging.basicConfig(level=logging.ERROR)

try:
    x = 10 / 0
except Exception as e:
    logging.exception("An error occurred")
# Out:
# ERROR:root:An error occurred
# Traceback (most recent call last):
#   File "/var/folders/hj/50_wmgmx4_d7lgrjh34hxgtw0000gn/T/ipykernel_28567/2476337194.py", line 7, in <module>
#     x = 10 / 0
#         ~~~^~~
# ZeroDivisionError: division by zero

# %% [markdown]
# #### shutil Module
#
# ##### Purpose
# - The shutil module provides high-level file and directory operations.
# - It simplifies common filesystem tasks like copying files, copying directories, moving files, and deleting directories — very useful in automation scripts, CI/CD pipelines, backups, and deployments.
#
# ##### Summary
# | Function     | Purpose             |
# | ------------ | ------------------- |
# | `copy()`     | Copy file           |
# | `copy2()`    | Copy with metadata  |
# | `copytree()` | Copy directory      |
# | `move()`     | Move file/directory |
# | `rmtree()`   | Delete directory    |

# %%
# Importing shutil
import shutil

# Copying Files
# Copy file (data + permissions)

shutil.copy("app.log", "backup_app.log")
# Out:
# 'backup_app.log'

# %%
# Copy file with metadata
shutil.copy2("app.log", "backup_app2.log")
# Out:
# 'backup_app2.log'

# %%
# Copying Directories
import shutil

shutil.copytree("project", "project_backup")
# Out:
# 'project_backup'

# %%
# Moving Files or Directories
import shutil

shutil.move("backup_app2.log","project_backup/")
# Out:
# 'project_backup/backup_app2.log'

# %%
# Removing Files & Directories
# Remove a directory (recursive delete)
import shutil

shutil.rmtree("temp_files")

# %%
# Real-world DevOps Examples
# Backup configuration files

import shutil

shutil.copy2("/etc/nginx/nginx.conf", "/backup/nginx.conf")

# Clean build artifacts in CI/CD
shutil.rmtree("build")
shutil.rmtree("dist")

# Deploy new version
shutil.move("release_v2/app", "/var/www/app")

# Combine with os.path (Very Common)
import os
import shutil

if os.path.exists("logs"):
    shutil.rmtree("logs")

# %% [markdown]
# #### math Module
#
# ##### Purpose
# - The math module provides basic mathematical functions useful in calculations, thresholds, limits, and resource planning in DevOps scripts.
#
# ##### Summary
# - math is for numerical calculations
# - Used in resource planning & automation
# - Faster and more accurate than manual calculations

# %%
# Importing math
import math

# Simple Square root
cpu_cores = 16
print(math.sqrt(cpu_cores))
# Out:
# 4.0

# %%
# Ceiling & Floor (rounding resource limits)
import math

memory = 2.3

print(math.ceil(memory))   # 3
print(math.floor(memory))  # 2
# Out:
# 3
# 2

# %%
# Power (capacity calculation)
import math

nodes = 2
print(math.pow(nodes, 3))   # 8.0
# Out:
# 8.0

# %%
# Constants
import math

print(math.pi)   # 3.141592653589793
# Out:
# 3.141592653589793

# %%
# Simple DevOps Use Case

# Check autoscaling threshold
import math

load = 7.6
required_instances = math.ceil(load)

print("Instances needed:", required_instances)
# Out:
# Instances needed: 8

# %% [markdown]
# #### datetime Module
#
# ##### Purpose
# - The datetime module is used to work with dates and times.
# - In DevOps, it’s commonly used for timestamps in logs, backups, monitoring, and automation scripts.
#
# ##### Summary
# - Used for logging timestamps
# - Helps in automation & backups
# - strftime() → format date/time

# %%
# Importing datetime
from datetime import datetime

# Get current date & time
now = datetime.now()
print(now)

# %%
# Format date & time (Very common)
now = datetime.now()

print(now.strftime("%Y-%m-%d"))
print(now.strftime("%H:%M:%S"))

# %%
# Timestamp for logs (DevOps use)
from datetime import datetime

print(f"Job started at {datetime.now()}")

# %%
# Use in file naming (Backups)
from datetime import datetime

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
filename = f"backup_{timestamp}.zip"

print(filename)
